# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Mosses\Desktop\covid_19worlddata.xlsx","covid_19worlddata")
df
# Out:
#       Id            Country  Total Cases  New Cases Total Deths  New Deaths  \
# 0      1                USA  1,71,59,794    14335.0    3,11,316       223.0
# 1      2              India    99,54,769    21861.0    1,44,353       223.0
# 2      3             Brazil    69,74,258        NaN    1,82,854         NaN
# 3      4             Russia    27,34,454    26509.0       48564       596.0
# 4      5             France    23,91,447        NaN       59072         NaN
# ..   ...                ...          ...        ...         ...         ...
# 215  216         MS Zaandam            9        NaN           2         NaN
# 216  217   Marshall Islands            4        NaN         NaN         NaN
# 217  218  Wallis and Futuna            3        NaN         NaN         NaN
# 218  219              Samoa            2        NaN         NaN         NaN
# 219  220            Vanuatu            1        NaN         NaN         NaN
#
# ...

# %%
ds=df.replace(" ",0)
ds
# Out:
#       Id            Country  Total Cases  New Cases Total Deths  New Deaths  \
# 0      1                USA  1,71,59,794    14335.0    3,11,316       223.0
# 1      2              India    99,54,769    21861.0    1,44,353       223.0
# 2      3             Brazil    69,74,258        NaN    1,82,854         NaN
# 3      4             Russia    27,34,454    26509.0       48564       596.0
# 4      5             France    23,91,447        NaN       59072         NaN
# ..   ...                ...          ...        ...         ...         ...
# 215  216         MS Zaandam            9        NaN           2         NaN
# 216  217   Marshall Islands            4        NaN         NaN         NaN
# 217  218  Wallis and Futuna            3        NaN         NaN         NaN
# 218  219              Samoa            2        NaN         NaN         NaN
# 219  220            Vanuatu            1        NaN         NaN         NaN
#
# ...

# %%
dg=ds.fillna(0)
dg
# Out:
#       Id            Country  Total Cases  New Cases Total Deths  New Deaths  \
# 0      1                USA  1,71,59,794    14335.0    3,11,316       223.0
# 1      2              India    99,54,769    21861.0    1,44,353       223.0
# 2      3             Brazil    69,74,258        0.0    1,82,854         0.0
# 3      4             Russia    27,34,454    26509.0       48564       596.0
# 4      5             France    23,91,447        0.0       59072         0.0
# ..   ...                ...          ...        ...         ...         ...
# 215  216         MS Zaandam            9        0.0           2         0.0
# 216  217   Marshall Islands            4        0.0           0         0.0
# 217  218  Wallis and Futuna            3        0.0           0         0.0
# 218  219              Samoa            2        0.0           0         0.0
# 219  220            Vanuatu            1        0.0           0         0.0
#
# ...

# %%
df.sort_values(by=['TotalCases/1Mpop'],ascending=False)
# Out:
#       Id           Country Total Cases  New Cases Total Deths  New Deaths  \
# 132  133           Andorra        7382        NaN          79         NaN
# 90    91        Luxembourg       42845      595.0         421         3.0
# 91    92        Montenegro       42563      415.0         610        13.0
# 164  165        San Marino        2025       43.0          54         2.0
# 109  110  French Polynesia       15870        NaN          97         NaN
# ..   ...               ...         ...        ...         ...         ...
# 184  185          Tanzania         509        NaN          21         NaN
# 203  204              Laos          41        NaN         NaN         NaN
# 219  220           Vanuatu           1        NaN         NaN         NaN
# 178  179  Diamond Princess         712        NaN          13         NaN
# 215  216        MS Zaandam           9        NaN           2         NaN
#
#     Total Recovered Active Cases   Serious Critical  TotalCases/1Mpop  \
# ...

# %%
df.sort_values(by=['Deaths/1Mpop'],ascending=False)
# Out:
#       Id                 Country Total Cases  New Cases Total Deths  \
# 164  165              San Marino        2025       43.0          54
# 20    21                 Belgium    6,11,422     2211.0       18178
# 15    16                    Peru    9,87,675        NaN       36817
# 6      7                   Italy   18,88,144    17572.0       66537
# 70    71  Bosnia and Herzegovina    1,03,232      902.0        3511
# ..   ...                     ...         ...        ...         ...
# 215  216              MS Zaandam           9        NaN           2
# 216  217        Marshall Islands           4        NaN         NaN
# 217  218       Wallis and Futuna           3        NaN         NaN
# 218  219                   Samoa           2        NaN         NaN
# 219  220                 Vanuatu           1        NaN         NaN
#
#      New Deaths Total Recovered Active Cases   Serious Critical  \
# 164         2.0            1694          277                5.0
# ...

# %%
var=df.sort_values(by=['TotalCases/1Mpop'],ascending=False)
x=var.head(50)
x
# Out:
#       Id                 Country  Total Cases  New Cases Total Deths  \
# 132  133                 Andorra         7382        NaN          79
# 90    91              Luxembourg        42845      595.0         421
# 91    92              Montenegro        42563      415.0         610
# 164  165              San Marino         2025       43.0          54
# 109  110        French Polynesia        15870        NaN          97
# 21    22                 Czechia     5,94,148     7889.0        9882
# 20    21                 Belgium     6,11,422     2211.0       18178
# 77    78                 Bahrain        89444        NaN         349
# 0      1                     USA  1,71,59,794    14335.0    3,11,316
# 51    52                 Armenia     1,50,218     1098.0        2556
# 56    57                   Qatar     1,41,417      145.0         242
# 41    42                 Georgia     1,98,387     3487.0        1922
# 71    72                Slovenia     1,00,389     2107.0        2190
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=50,10
df.plot.bar()

# %%
plt.rcParams["figure.figsize"]=40,40
dg.plot.bar(x="Country", y=["TotalCases/1Mpop"])

# %%
plt.rcParams["figure.figsize"]=40,40
dg.plot.bar(x="Country", y=["Deaths/1Mpop"])

# %%
plt.rcParams["figure.figsize"]=200,60
dg.plot.bar( x='Country',rot=0, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x3016C250>,
# ...
#       dtype=object)

# %%
print("Maximum: ",df["Deaths/1Mpop"].max())
# Out:
# Maximum:  1590.0

# %%
print("Maximum: ",df["TotalCases/1Mpop"].max())
# Out:
# Maximum:  95471.0

# %%
print(df.max())
# Out:
# Id                        220
# Country              Zimbabwe
# New Cases               26509
# New Deaths                801
#  Serious Critical       28304
# TotalCases/1Mpop        95471
# Deaths/1Mpop             1590
# dtype: object

# %%
print(df.min())
# Out:
# Id                             1
# Country              Afghanistan
# New Cases                      1
# New Deaths                     1
#  Serious Critical              1
# TotalCases/1Mpop               3
# Deaths/1Mpop                0.08
# dtype: object
