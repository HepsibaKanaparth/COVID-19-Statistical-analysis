# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Mosses\Desktop\who.xlsx","who")
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                  72196732
# 1    United States of America         Americas                  16245376
# 2                       India  South-East Asia                   9932547
# 3                      Brazil         Americas                   6927145
# 4          Russian Federation           Europe                   2734454
# ..                        ...              ...                       ...
# 231                     Samoa  Western Pacific                         0
# 232                   Tokelau  Western Pacific                         0
# 233                     Tonga  Western Pacific                         0
# 234              Turkmenistan           Europe                         0
# 235                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 1 million population  \
# ...

# %%
print(df.min())
# Out:
# Name                                                  Afghanistan
# Cases - cumulative total                                        0
# Cases - cumulative total per 1 million population               0
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 24 hours                        -1
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 1 million population              0
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 24 hours                        0
# dtype: object

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=40,20
df.plot.bar()

# %%
plt.rcParams["figure.figsize"]=40,20
df[['Cases - cumulative total']].plot.bar()

# %%
plt.rcParams["figure.figsize"]=40,20
df[['Deaths - cumulative total']].plot.bar()

# %%
plt.rcParams["figure.figsize"]=250,60
df.plot.bar( x='Name',rot=0, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x2BD9B388>,
# ...
#       dtype=object)

# %%
x=df.head(15)
x
# Out:
#                           Name             WHO Region  \
# 0                       Global                    NaN
# 1     United States of America               Americas
# 2                        India        South-East Asia
# 3                       Brazil               Americas
# 4           Russian Federation                 Europe
# 5                       France                 Europe
# 6           The United Kingdom                 Europe
# 7                        Italy                 Europe
# 8                        Spain                 Europe
# 9                    Argentina               Americas
# 10                    Colombia               Americas
# 11                     Germany                 Europe
# 12                      Mexico               Americas
# 13                      Poland                 Europe
# 14  Iran (Islamic Republic of)  Eastern Mediterranean
#
#     Cases - cumulative total  \
# 0                   72196732
# 1                   16245376
# ...

# %%
plt.rcParams["figure.figsize"]=40,40
x.plot.bar(x="Name", y=["Cases - cumulative total"])

# %%
plt.rcParams["figure.figsize"]=40,40
x.plot.bar(x="Name", y=["Deaths - cumulative total"])

# %%
plt.rcParams["figure.figsize"]=40,40
x.plot.bar(x="Name", y=["Cases - newly reported in last 7 days"])

# %%
plt.rcParams["figure.figsize"]=40,40
x.plot.bar(x="Name", y=["Deaths - newly reported in last 7 days"])

# %%
x.plot(x="Name", y=["Cases - cumulative total", "Deaths - cumulative total"], kind="bar")

# %%
x.plot(x="Name", y=["Cases - newly reported in last 7 days", "Deaths - newly reported in last 7 days"], kind="bar")

# %%
df.sort_values(by=['Cases - cumulative total'],ascending=False)
# Out:
#                                       Name       WHO Region  \
# 0                                   Global              NaN
# 1                 United States of America         Americas
# 2                                    India  South-East Asia
# 3                                   Brazil         Americas
# 4                       Russian Federation           Europe
# ..                                     ...              ...
# 225       Micronesia (Federated States of)  Western Pacific
# 224                               Kiribati  Western Pacific
# 223  Democratic People's Republic of Korea  South-East Asia
# 221                         American Samoa  Western Pacific
# 235                                 Tuvalu  Western Pacific
#
#      Cases - cumulative total  \
# 0                    72196732
# 1                    16245376
# 2                     9932547
# 3                     6927145
# 4                     2734454
# ..                        ...
# ...

# %%
df.sort_values(by=['Deaths - cumulative total'],ascending=False)
# Out:
#                             Name       WHO Region  Cases - cumulative total  \
# 0                         Global              NaN                  72196732
# 1       United States of America         Americas                  16245376
# 3                         Brazil         Americas                   6927145
# 2                          India  South-East Asia                   9932547
# 12                        Mexico         Americas                   1255974
# ..                           ...              ...                       ...
# 210        Saint Kitts and Nevis         Americas                        28
# 211                     Holy See           Europe                        26
# 212  Falkland Islands (Malvinas)         Americas                        19
# 213                    Greenland           Europe                        19
# 235                       Tuvalu  Western Pacific                         0
#
# ...

# %%
df.sort_values(by=['Cases - newly reported in last 7 days'],ascending=False)
# Out:
#                                  Name       WHO Region  \
# 0                              Global              NaN
# 1            United States of America         Americas
# 3                              Brazil         Americas
# 15                             Turkey           Europe
# 2                               India  South-East Asia
# ..                                ...              ...
# 207  Lao People's Democratic Republic  Western Pacific
# 187       United Republic of Tanzania           Africa
# 151                         Nicaragua         Americas
# 199                 Brunei Darussalam  Western Pacific
# 235                            Tuvalu  Western Pacific
#
#      Cases - cumulative total  \
# 0                    72196732
# 1                    16245376
# 3                     6927145
# 15                    1084109
# 2                     9932547
# ..                        ...
# 207                        41
# 187                       509
# ...

# %%
df.sort_values(by=['Deaths - newly reported in last 7 days'],ascending=False)
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                  72196732
# 1    United States of America         Americas                  16245376
# 7                       Italy           Europe                   1870576
# 3                      Brazil         Americas                   6927145
# 12                     Mexico         Americas                   1255974
# ..                        ...              ...                       ...
# 173              Sint Maarten         Americas                      1249
# 172                  Viet Nam  Western Pacific                      1405
# 170               New Zealand  Western Pacific                      1744
# 169                   Liberia           Africa                      1771
# 235                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 1 million population  \
# ...

# %%
df.sort_values(by=['Cases - newly reported in last 7 days'],ascending=True)
# Out:
#                             Name             WHO Region  \
# 235                       Tuvalu        Western Pacific
# 234                 Turkmenistan                 Europe
# 187  United Republic of Tanzania                 Africa
# 152                      Somalia  Eastern Mediterranean
# 199            Brunei Darussalam        Western Pacific
# ..                           ...                    ...
# 2                          India        South-East Asia
# 15                        Turkey                 Europe
# 3                         Brazil               Americas
# 1       United States of America               Americas
# 0                         Global                    NaN
#
#      Cases - cumulative total  \
# 235                         0
# 234                         0
# 187                       509
# 152                      4579
# 199                       152
# ..                        ...
# 2                     9932547
# 15                    1084109
# ...

# %%
df.sort_values(by=['Deaths - newly reported in last 7 days'],ascending=True)
# Out:
#                              Name       WHO Region  Cases - cumulative total  \
# 235                        Tuvalu  Western Pacific                         0
# 167  United States Virgin Islands         Americas                      1828
# 168                          Chad           Africa                      1784
# 169                       Liberia           Africa                      1771
# 170                   New Zealand  Western Pacific                      1744
# ..                            ...              ...                       ...
# 12                         Mexico         Americas                   1255974
# 3                          Brazil         Americas                   6927145
# 7                           Italy           Europe                   1870576
# 1        United States of America         Americas                  16245376
# 0                          Global              NaN                  72196732
#
# ...

# %%
w=df.groupby("Transmission Classification")["Transmission Classification"].count()
w.head(15)
# Out:
# Transmission Classification
# Clusters of cases          53
# Community transmission    127
# No cases                   19
# Not applicable              1
# Pending                     2
# Sporadic cases             33
# Name: Transmission Classification, dtype: int64

# %%
w=df.groupby("Transmission Classification")["Transmission Classification"].count()
w.head(15).plot(kind="bar")

# %%
x.head(15).plot(x="Cases - newly reported in last 7 days", y= "Deaths - newly reported in last 7 days", kind="bar")

# %%
x.head(15).plot(x="Cases - cumulative total", y= "Deaths - cumulative total", kind="bar")

# %%
x.head(15).plot(x="Cases - newly reported in last 24 hours", y= "Deaths - newly reported in last 24 hours", kind="bar")

# %%
df.loc[df['Name'] == 'China']
# Out:
#      Name       WHO Region  Cases - cumulative total  \
# 74  China  Western Pacific                     95279
#
#     Cases - cumulative total per 1 million population  \
# 74                                              64.76
#
#     Cases - newly reported in last 7 days  \
# 74                                    779
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 74                                      112                       4764
#
#     Deaths - cumulative total per 1 million population  \
# 74                                               3.24
#
#     Deaths - newly reported in last 7 days  \
# 74                                      11
#
#     Deaths - newly reported in last 24 hours Transmission Classification
# 74                                         3           Clusters of cases
